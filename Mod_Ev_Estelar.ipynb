# %% [markdown]
# <a href="https://colab.research.google.com/github/gonzalo-marrero/stellar_evolution_models/blob/main/Mod_Ev_Estelar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Evolución modelos estelares

# %% [markdown]
# ## Importar paquetes. Importar datos y asignación de variables

# %%
pip install astropy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#Importación de los módulos:
from astropy.io.ascii import read
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %%
#Importación de archivos:
myfile1 = read('data/M0p8_2.txt')   # Estrella 0.8 M☉
myfile2 = read('data/M1.txt')       # Estrella 1 M☉
myfile3 = read('data/M1p25.txt')    # Estrella 1.25 M☉
myfile4 = read('data/M1p5.txt')     # Estrella 1.5 M☉
myfile5 = read('data/M2.txt')       # Estrella 2 M☉
myfile6 = read('data/M3.txt')       # Estrella 3 M☉
myfile7 = read('data/M5.txt')       # Estrella 5 M☉
myfile8 = read('data/M9.txt')       # Estrella 9 M☉
myfile9 = read('data/M15.txt')      # Estrella 15 M☉
myfile10 = read('data/M25.txt')     # Estrella 25 M☉
myfile11 = read('data/M40.txt')     # Estrella 40 M☉

# %%
#Asignación de las variables a la estrella 0.8Msun:#
####################################################
xx = myfile1['time'] #Tiempo en (yr)
yy = myfile1['mass'] #Masa en (Msun)
zz = myfile1['lg(L)'] #Log de la luminosidad (en Lsun)
aa = myfile1['1H_surf'] # 1H superficial (Fracc. en masa)
bb = myfile1['4He_surf'] # 4He superficial (Fracc. en masa)
cc = myfile1['12C_surf'] # 12C superficial (Fracc. en masa)
dd = myfile1['13C_surf'] # 13C superficial (Fracc. en masa)
ee = myfile1['14N_surf'] # 14N superficial (Fracc. en masa)
ff = myfile1['16O_surf'] # 16_O superficial (Fracc. en masa)
gg = myfile1['17O_surf'] # 17_O superficial (Fracc. en masa)
hh = myfile1['18O_surf'] # 18_O superficial (Fracc. en masa)
ii = myfile1['20Ne_surf'] # 20Ne superficial (Fracc. en masa)
jj = myfile1['22Ne_surf'] # 22Ne superficial (Fracc. en masa)
kk = myfile1['26Al_surf'] # 26_Al superficial (Fracc. en masa)
ll = myfile1['Mcc/Mt'] # Ratio Mc/Mt
mm=  myfile1['lg(Teff)'] # Log Temperatura (K)
nn = myfile1['lg(Md)'] # Log Ms/yr
oo = myfile1['lg(rhoc)'] # Log rho crítica (g/cm3)
pp = myfile1['lg(Tc)'] # Log T crítica (K)
qq = myfile1['1H_cen'] # 1H central (Fracc. en masa)
rr = myfile1['4He_cen'] # 4He central (Fracc. en masa)
ss = myfile1['12C_cen'] # 12C central (Fracc. en masa)
tt = myfile1['13C_cen'] # 13C central (Fracc. en masa)
uu = myfile1['14N_cen'] # 14N central (Fracc. en masa)
vv = myfile1['16O_cen'] # 16_O central (Fracc. en masa)
ww = myfile1['17O_cen'] # 17_O central (Fracc. en masa)
xxx = myfile1['18O_cen'] # 18_O central (Fracc. en masa)
yyy = myfile1['20Ne_cen'] # 20Ne central (Fracc. en masa)
zzz = myfile1['22Ne_cen'] # 22Ne central (Fracc. en masa)
aaa = myfile1['26Al_cen'] # 26_Al central (Fracc. en masa)
bbb = myfile1['Omeg_surf'] # Omega superficial  (s-1)
ccc = myfile1['Omeg_cen'] # Omega central  (s-1)
ddd = myfile1['Rp/Req'] # Rp/Requiv
eee = myfile1['Md/Md(0)'] # Md/Md(0)
fff = myfile1['v_crit1'] # Velocidad crítica 1 (km/s)
ggg = myfile1['v_crit2'] # Velocidad crítica 2 (km/s)
hhh = myfile1['v_equa'] # Velocidad crítica 2 (km/s)
iii = myfile1['Om/Om_cr'] # Omega/ Omega crítica
jjj = myfile1['Gamma_Ed'] # Gamma de Eddington
kkk = myfile1['lg(Mdot_mech)'] #log Msun (Msun/yr)
lll = myfile1['L_tot'] #Luminosidad total
####################################################
#Asignación de las variables a la estrella de 1Msun:
####################################################

xx1 = myfile2['time'] #Tiempo en (yr)
yy1 = myfile2['mass'] #Masa en (Msun)
zz1 = myfile2['lg(L)'] #Log de la luminosidad (en Lsun)
aa1 = myfile2['1H_surf'] # 1H superficial (Fracc. en masa)
bb1 = myfile2['4He_surf'] # 4He superficial (Fracc. en masa)
cc1 = myfile2['12C_surf'] # 12C superficial (Fracc. en masa)
dd1 = myfile2['13C_surf'] # 13C superficial (Fracc. en masa)
ee1 = myfile2['14N_surf'] # 14N superficial (Fracc. en masa)
ff1 = myfile2['16O_surf'] # 16_O superficial (Fracc. en masa)
gg1 = myfile2['17O_surf'] # 17_O superficial (Fracc. en masa)
hh1 = myfile2['18O_surf'] # 18_O superficial (Fracc. en masa)
ii1 = myfile2['20Ne_surf'] # 20Ne superficial (Fracc. en masa)
jj1 = myfile2['22Ne_surf'] # 22Ne superficial (Fracc. en masa)
kk1 = myfile2['26Al_surf'] # 26_Al superficial (Fracc. en masa)
ll1 = myfile2['Mcc/Mt'] # Ratio Mcc/Mt
mm1 =  myfile2['lg(Teff)'] # Log Temperatura (K)
nn1 = myfile2['lg(Md)'] # Log Ms/yr
oo1 = myfile2['lg(rhoc)'] # Log rho crítica (g/cm3)
pp1 = myfile2['lg(Tc)'] # Log T crítica (K)
qq1 = myfile2['1H_cen'] # 1H central (Fracc. en masa)
rr1 = myfile2['4He_cen'] # 4He central (Fracc. en masa)
ss1 = myfile2['12C_cen'] # 12C central (Fracc. en masa)
tt1 = myfile2['13C_cen'] # 13C central (Fracc. en masa)
uu1 = myfile2['14N_cen'] # 14N central (Fracc. en masa)
vv1 = myfile2['16O_cen'] # 16_O central (Fracc. en masa)
ww1 = myfile2['17O_cen'] # 17_O central (Fracc. en masa)
xxx1 = myfile2['18O_cen'] # 18_O central (Fracc. en masa)
yyy1 = myfile2['20Ne_cen'] # 20Ne central (Fracc. en masa)
zzz1 = myfile2['22Ne_cen'] # 22Ne central (Fracc. en masa)
aaa1 = myfile2['26Al_cen'] # 26_Al central (Fracc. en masa)
bbb1 = myfile2['Omeg_surf'] # Omega superficial  (s-1)
ccc1 = myfile2['Omeg_cen'] # Omega central  (s-1)
ddd1 = myfile2['Rp/Req'] # Rp/Requiv
eee1 = myfile2['Md/Md(0)'] # Md/Md(0)
fff1 = myfile2['v_crit1'] # Velocidad crítica 1 (km/s)
ggg1 = myfile2['v_crit2'] # Velocidad crítica 2 (km/s)
hhh1 = myfile2['v_equa'] # Velocidad crítica 2 (km/s)
iii1 = myfile2['Om/Om_cr'] # Omega/ Omega crítica
jjj1 = myfile2['Gamma_Ed'] # Gamma de Eddington
kkk1 = myfile2['lg(Mdot_mech)'] #log Msun (Msun/yr)
lll1 = myfile2['L_tot'] #Luminosidad total

####################################################
#Asignación de las variables a la estrella de 1.25Msun:
####################################################

xx2 = myfile3['time'] #Tiempo en (yr)
yy2 = myfile3['mass'] #Masa en (Msun)
zz2 = myfile3['lg(L)'] #Log de la luminosidad (en Lsun)
aa2 = myfile3['1H_surf'] # 1H superficial (Fracc. en masa)
bb2 = myfile3['4He_surf'] # 4He superficial (Fracc. en masa)
cc2 = myfile3['12C_surf'] # 12C superficial (Fracc. en masa)
dd2 = myfile3['13C_surf'] # 13C superficial (Fracc. en masa)
ee2 = myfile3['14N_surf'] # 14N superficial (Fracc. en masa)
ff2 = myfile3['16O_surf'] # 16_O superficial (Fracc. en masa)
gg2 = myfile3['17O_surf'] # 17_O superficial (Fracc. en masa)
hh2 = myfile3['18O_surf'] # 18_O superficial (Fracc. en masa)
ii2 = myfile3['20Ne_surf'] # 20Ne superficial (Fracc. en masa)
jj2 = myfile3['22Ne_surf'] # 22Ne superficial (Fracc. en masa)
kk2 = myfile3['26Al_surf'] # 26_Al superficial (Fracc. en masa)
ll2 = myfile3['Mcc/Mt'] # Ratio Mcc/Mt
mm2 =  myfile3['lg(Teff)'] # Log Temperatura (K)
nn2 = myfile3['lg(Md)'] # Log Ms/yr
oo2 = myfile3['lg(rhoc)'] # Log rho crítica (g/cm3)
pp2 = myfile3['lg(Tc)'] # Log T crítica (K)
qq2 = myfile3['1H_cen'] # 1H central (Fracc. en masa)
rr2 = myfile3['4He_cen'] # 4He central (Fracc. en masa)
ss2 = myfile3['12C_cen'] # 12C central (Fracc. en masa)
tt2 = myfile3['13C_cen'] # 13C central (Fracc. en masa)
uu2 = myfile3['14N_cen'] # 14N central (Fracc. en masa)
vv2 = myfile3['16O_cen'] # 16_O central (Fracc. en masa)
ww2 = myfile3['17O_cen'] # 17_O central (Fracc. en masa)
xxx2 = myfile3['18O_cen'] # 18_O central (Fracc. en masa)
yyy2 = myfile3['20Ne_cen'] # 20Ne central (Fracc. en masa)
zzz2 = myfile3['22Ne_cen'] # 22Ne central (Fracc. en masa)
aaa2 = myfile3['26Al_cen'] # 26_Al central (Fracc. en masa)
bbb2 = myfile3['Omeg_surf'] # Omega superficial  (s-1)
ccc2 = myfile3['Omeg_cen'] # Omega central  (s-1)
ddd2 = myfile3['Rp/Req'] # Rp/Requiv
eee2 = myfile3['Md/Md(0)'] # Md/Md(0)
fff2 = myfile3['v_crit1'] # Velocidad crítica 1 (km/s)
ggg2 = myfile3['v_crit2'] # Velocidad crítica 2 (km/s)
hhh2 = myfile3['v_equa'] # Velocidad crítica 2 (km/s)
iii2 = myfile3['Om/Om_cr'] # Omega/ Omega crítica
jjj2 = myfile3['Gamma_Ed'] # Gamma de Eddington
kkk2 = myfile3['lg(Mdot_mech)'] #log Msun (Msun/yr)
lll2 = myfile3['L_tot'] #Luminosidad total

####################################################
#Asignación de las variables a la estrella de 1.5Msun:
####################################################

xx3 = myfile4['time'] #Tiempo en (yr)
yy3 = myfile4['mass'] #Masa en (Msun)
zz3 = myfile4['lg(L)'] #Log de la luminosidad (en Lsun)
aa3 = myfile4['1H_surf'] # 1H superficial (Fracc. en masa)
bb3 = myfile4['4He_surf'] # 4He superficial (Fracc. en masa)
cc3 = myfile4['12C_surf'] # 12C superficial (Fracc. en masa)
dd3 = myfile4['13C_surf'] # 13C superficial (Fracc. en masa)
ee3 = myfile4['14N_surf'] # 14N superficial (Fracc. en masa)
ff3 = myfile4['16O_surf'] # 16_O superficial (Fracc. en masa)
gg3 = myfile4['17O_surf'] # 17_O superficial (Fracc. en masa)
hh3 = myfile4['18O_surf'] # 18_O superficial (Fracc. en masa)
ii3 = myfile4['20Ne_surf'] # 20Ne superficial (Fracc. en masa)
jj3 = myfile4['22Ne_surf'] # 22Ne superficial (Fracc. en masa)
kk3 = myfile4['26Al_surf'] # 26_Al superficial (Fracc. en masa)
ll3 = myfile4['Mcc/Mt'] # Ratio Mcc/Mt
mm3 =  myfile4['lg(Teff)'] # Log Temperatura (K)
nn3 = myfile4['lg(Md)'] # Log Ms/yr
oo3 = myfile4['lg(rhoc)'] # Log rho crítica (g/cm3)
pp3 = myfile4['lg(Tc)'] # Log T crítica (K)
qq3 = myfile4['1H_cen'] # 1H central (Fracc. en masa)
rr3 = myfile4['4He_cen'] # 4He central (Fracc. en masa)
ss3 = myfile4['12C_cen'] # 12C central (Fracc. en masa)
tt3 = myfile4['13C_cen'] # 13C central (Fracc. en masa)
uu3 = myfile4['14N_cen'] # 14N central (Fracc. en masa)
vv3 = myfile4['16O_cen'] # 16_O central (Fracc. en masa)
ww3 = myfile4['17O_cen'] # 17_O central (Fracc. en masa)
xxx3 = myfile4['18O_cen'] # 18_O central (Fracc. en masa)
yyy3 = myfile4['20Ne_cen'] # 20Ne central (Fracc. en masa)
zzz3 = myfile4['22Ne_cen'] # 22Ne central (Fracc. en masa)
aaa3 = myfile4['26Al_cen'] # 26_Al central (Fracc. en masa)
bbb3 = myfile4['Omeg_surf'] # Omega superficial  (s-1)
ccc3 = myfile4['Omeg_cen'] # Omega central  (s-1)
ddd3 = myfile4['Rp/Req'] # Rp/Requiv
eee3 = myfile4['Md/Md(0)'] # Md/Md(0)
fff3 = myfile4['v_crit1'] # Velocidad crítica 1 (km/s)
ggg3 = myfile4['v_crit2'] # Velocidad crítica 2 (km/s)
hhh3 = myfile4['v_equa'] # Velocidad crítica 2 (km/s)
iii3 = myfile4['Om/Om_cr'] # Omega/ Omega crítica
jjj3 = myfile4['Gamma_Ed'] # Gamma de Eddington
kkk3 = myfile4['lg(Mdot_mech)'] #log Msun (Msun/yr)
lll3 = myfile4['L_tot'] #Luminosidad total

####################################################
#Asignación de las variables a la estrella de 2.0Msun:
####################################################

xx4 = myfile5['time'] #Tiempo en (yr)
yy4 = myfile5['mass'] #Masa en (Msun)
zz4 = myfile5['lg(L)'] #Log de la luminosidad (en Lsun)
aa4 = myfile5['1H_surf'] # 1H superficial (Fracc. en masa)
bb4 = myfile5['4He_surf'] # 4He superficial (Fracc. en masa)
cc4 = myfile5['12C_surf'] # 12C superficial (Fracc. en masa)
dd4 = myfile5['13C_surf'] # 13C superficial (Fracc. en masa)
ee4 = myfile5['14N_surf'] # 14N superficial (Fracc. en masa)
ff4 = myfile5['16O_surf'] # 16_O superficial (Fracc. en masa)
gg4 = myfile5['17O_surf'] # 17_O superficial (Fracc. en masa)
hh4 = myfile5['18O_surf'] # 18_O superficial (Fracc. en masa)
ii4 = myfile5['20Ne_surf'] # 20Ne superficial (Fracc. en masa)
jj4 = myfile5['22Ne_surf'] # 22Ne superficial (Fracc. en masa)
kk4 = myfile5['26Al_surf'] # 26_Al superficial (Fracc. en masa)
ll4 = myfile5['Mcc/Mt'] # Ratio Mcc/Mt
mm4 =  myfile5['lg(Teff)'] # Log Temperatura (K)
nn4 = myfile5['lg(Md)'] # Log Ms/yr
oo4 = myfile5['lg(rhoc)'] # Log rho crítica (g/cm3)
pp4 = myfile5['lg(Tc)'] # Log T crítica (K)
qq4 = myfile5['1H_cen'] # 1H central (Fracc. en masa)
rr4 = myfile5['4He_cen'] # 4He central (Fracc. en masa)
ss4 = myfile5['12C_cen'] # 12C central (Fracc. en masa)
tt4 = myfile5['13C_cen'] # 13C central (Fracc. en masa)
uu4 = myfile5['14N_cen'] # 14N central (Fracc. en masa)
vv4 = myfile5['16O_cen'] # 16_O central (Fracc. en masa)
ww4 = myfile5['17O_cen'] # 17_O central (Fracc. en masa)
xxx4 = myfile5['18O_cen'] # 18_O central (Fracc. en masa)
yyy4 = myfile5['20Ne_cen'] # 20Ne central (Fracc. en masa)
zzz4 = myfile5['22Ne_cen'] # 22Ne central (Fracc. en masa)
aaa4 = myfile5['26Al_cen'] # 26_Al central (Fracc. en masa)
bbb4 = myfile5['Omeg_surf'] # Omega superficial  (s-1)
ccc4 = myfile5['Omeg_cen'] # Omega central  (s-1)
ddd4 = myfile5['Rp/Req'] # Rp/Requiv
eee4 = myfile5['Md/Md(0)'] # Md/Md(0)
fff4 = myfile5['v_crit1'] # Velocidad crítica 1 (km/s)
ggg4 = myfile5['v_crit2'] # Velocidad crítica 2 (km/s)
hhh4 = myfile5['v_equa'] # Velocidad crítica 2 (km/s)
iii4 = myfile5['Om/Om_cr'] # Omega/ Omega crítica
jjj4 = myfile5['Gamma_Ed'] # Gamma de Eddington
kkk4 = myfile5['lg(Mdot_mech)'] #log Msun (Msun/yr)
lll4 = myfile5['L_tot'] #Luminosidad total

####################################################
#Asignación de las variables a la estrella de 3.0Msun:
####################################################

xx5 = myfile6['time'] #Tiempo en (yr)
yy5 = myfile6['mass'] #Masa en (Msun)
zz5 = myfile6['lg(L)'] #Log de la luminosidad (en Lsun)
aa5 = myfile6['1H_surf'] # 1H superficial (Fracc. en masa)
bb5 = myfile6['4He_surf'] # 4He superficial (Fracc. en masa)
cc5 = myfile6['12C_surf'] # 12C superficial (Fracc. en masa)
dd5 = myfile6['13C_surf'] # 13C superficial (Fracc. en masa)
ee5 = myfile6['14N_surf'] # 14N superficial (Fracc. en masa)
ff5 = myfile6['16O_surf'] # 16_O superficial (Fracc. en masa)
gg5 = myfile6['17O_surf'] # 17_O superficial (Fracc. en masa)
hh5 = myfile6['18O_surf'] # 18_O superficial (Fracc. en masa)
ii5 = myfile6['20Ne_surf'] # 20Ne superficial (Fracc. en masa)
jj5 = myfile6['22Ne_surf'] # 22Ne superficial (Fracc. en masa)
kk5 = myfile6['26Al_surf'] # 26_Al superficial (Fracc. en masa)
ll5 = myfile6['Mcc/Mt'] # Ratio Mcc/Mt
mm5 =  myfile6['lg(Teff)'] # Log Temperatura (K)
nn5 = myfile6['lg(Md)'] # Log Ms/yr
oo5 = myfile6['lg(rhoc)'] # Log rho crítica (g/cm3)
pp5 = myfile6['lg(Tc)'] # Log T crítica (K)
qq5 = myfile6['1H_cen'] # 1H central (Fracc. en masa)
rr5 = myfile6['4He_cen'] # 4He central (Fracc. en masa)
ss5 = myfile6['12C_cen'] # 12C central (Fracc. en masa)
tt5 = myfile6['13C_cen'] # 13C central (Fracc. en masa)
uu5 = myfile6['14N_cen'] # 14N central (Fracc. en masa)
vv5 = myfile6['16O_cen'] # 16_O central (Fracc. en masa)
ww5 = myfile6['17O_cen'] # 17_O central (Fracc. en masa)
xxx5 = myfile6['18O_cen'] # 18_O central (Fracc. en masa)
yyy5 = myfile6['20Ne_cen'] # 20Ne central (Fracc. en masa)
zzz5 = myfile6['22Ne_cen'] # 22Ne central (Fracc. en masa)
aaa5 = myfile6['26Al_cen'] # 26_Al central (Fracc. en masa)
bbb5 = myfile6['Omeg_surf'] # Omega superficial  (s-1)
ccc5 = myfile6['Omeg_cen'] # Omega central  (s-1)
ddd5 = myfile6['Rp/Req'] # Rp/Requiv
eee5 = myfile6['Md/Md(0)'] # Md/Md(0)
fff5 = myfile6['v_crit1'] # Velocidad crítica 1 (km/s)
ggg5 = myfile6['v_crit2'] # Velocidad crítica 2 (km/s)
hhh5 = myfile6['v_equa'] # Velocidad crítica 2 (km/s)
iii5 = myfile6['Om/Om_cr'] # Omega/ Omega crítica
jjj5 = myfile6['Gamma_Ed'] # Gamma de Eddington
kkk5 = myfile6['lg(Mdot_mech)'] #log Msun (Msun/yr)
lll5 = myfile6['L_tot'] #Luminosidad total

####################################################
#Asignación de las variables a la estrella de 5.0Msun:
####################################################

xx6 = myfile7['time'] #Tiempo en (yr)
yy6 = myfile7['mass'] #Masa en (Msun)
zz6 = myfile7['lg(L)'] #Log de la luminosidad (en Lsun)
aa6 = myfile7['1H_surf'] # 1H superficial (Fracc. en masa)
bb6 = myfile7['4He_surf'] # 4He superficial (Fracc. en masa)
cc6 = myfile7['12C_surf'] # 12C superficial (Fracc. en masa)
dd6 = myfile7['13C_surf'] # 13C superficial (Fracc. en masa)
ee6 = myfile7['14N_surf'] # 14N superficial (Fracc. en masa)
ff6 = myfile7['16O_surf'] # 16_O superficial (Fracc. en masa)
gg6 = myfile7['17O_surf'] # 17_O superficial (Fracc. en masa)
hh6 = myfile7['18O_surf'] # 18_O superficial (Fracc. en masa)
ii6 = myfile7['20Ne_surf'] # 20Ne superficial (Fracc. en masa)
jj6 = myfile7['22Ne_surf'] # 22Ne superficial (Fracc. en masa)
kk6 = myfile7['26Al_surf'] # 26_Al superficial (Fracc. en masa)
ll6 = myfile7['Mcc/Mt'] # Ratio Mcc/Mt
mm6 =  myfile7['lg(Teff)'] # Log Temperatura (K)
nn6 = myfile7['lg(Md)'] # Log Ms/yr
oo6 = myfile7['lg(rhoc)'] # Log rho crítica (g/cm3)
pp6 = myfile7['lg(Tc)'] # Log T crítica (K)
qq6 = myfile7['1H_cen'] # 1H central (Fracc. en masa)
rr6 = myfile7['4He_cen'] # 4He central (Fracc. en masa)
ss6 = myfile7['12C_cen'] # 12C central (Fracc. en masa)
tt6 = myfile7['13C_cen'] # 13C central (Fracc. en masa)
uu6 = myfile7['14N_cen'] # 14N central (Fracc. en masa)
vv6 = myfile7['16O_cen'] # 16_O central (Fracc. en masa)
ww6 = myfile7['17O_cen'] # 17_O central (Fracc. en masa)
xxx6 = myfile7['18O_cen'] # 18_O central (Fracc. en masa)
yyy6 = myfile7['20Ne_cen'] # 20Ne central (Fracc. en masa)
zzz6 = myfile7['22Ne_cen'] # 22Ne central (Fracc. en masa)
aaa6 = myfile7['26Al_cen'] # 26_Al central (Fracc. en masa)
bbb6 = myfile7['Omeg_surf'] # Omega superficial  (s-1)
ccc6 = myfile7['Omeg_cen'] # Omega central  (s-1)
ddd6 = myfile7['Rp/Req'] # Rp/Requiv
eee6 = myfile7['Md/Md(0)'] # Md/Md(0)
fff6 = myfile7['v_crit1'] # Velocidad crítica 1 (km/s)
ggg6 = myfile7['v_crit2'] # Velocidad crítica 2 (km/s)
hhh6 = myfile7['v_equa'] # Velocidad crítica 2 (km/s)
iii6 = myfile7['Om/Om_cr'] # Omega/ Omega crítica
jjj6 = myfile7['Gamma_Ed'] # Gamma de Eddington
kkk6 = myfile7['lg(Mdot_mech)'] #log Msun (Msun/yr)
lll6 = myfile7['L_tot'] #Luminosidad total

####################################################
#Asignación de las variables a la estrella de 9.0Msun:
####################################################

xx7 = myfile8['time'] #Tiempo en (yr)
yy7 = myfile8['mass'] #Masa en (Msun)
zz7 = myfile8['lg(L)'] #Log de la luminosidad (en Lsun)
aa7 = myfile8['1H_surf'] # 1H superficial (Fracc. en masa)
bb7 = myfile8['4He_surf'] # 4He superficial (Fracc. en masa)
cc7 = myfile8['12C_surf'] # 12C superficial (Fracc. en masa)
dd7 = myfile8['13C_surf'] # 13C superficial (Fracc. en masa)
ee7 = myfile8['14N_surf'] # 14N superficial (Fracc. en masa)
ff7 = myfile8['16O_surf'] # 16_O superficial (Fracc. en masa)
gg7 = myfile8['17O_surf'] # 17_O superficial (Fracc. en masa)
hh7 = myfile8['18O_surf'] # 18_O superficial (Fracc. en masa)
ii7 = myfile8['20Ne_surf'] # 20Ne superficial (Fracc. en masa)
jj7 = myfile8['22Ne_surf'] # 22Ne superficial (Fracc. en masa)
kk7 = myfile8['26Al_surf'] # 26_Al superficial (Fracc. en masa)
ll7 = myfile8['Mcc/Mt'] # Ratio Mcc/Mt
mm7 =  myfile8['lg(Teff)'] # Log Temperatura (K)
nn7 = myfile8['lg(Md)'] # Log Ms/yr
oo7 = myfile8['lg(rhoc)'] # Log rho crítica (g/cm3)
pp7 = myfile8['lg(Tc)'] # Log T crítica (K)
qq7 = myfile8['1H_cen'] # 1H central (Fracc. en masa)
rr7 = myfile8['4He_cen'] # 4He central (Fracc. en masa)
ss7 = myfile8['12C_cen'] # 12C central (Fracc. en masa)
tt7 = myfile8['13C_cen'] # 13C central (Fracc. en masa)
uu7 = myfile8['14N_cen'] # 14N central (Fracc. en masa)
vv7 = myfile8['16O_cen'] # 16_O central (Fracc. en masa)
ww7 = myfile8['17O_cen'] # 17_O central (Fracc. en masa)
xxx7 = myfile8['18O_cen'] # 18_O central (Fracc. en masa)
yyy7 = myfile8['20Ne_cen'] # 20Ne central (Fracc. en masa)
zzz7 = myfile8['22Ne_cen'] # 22Ne central (Fracc. en masa)
aaa7 = myfile8['26Al_cen'] # 26_Al central (Fracc. en masa)
bbb7 = myfile8['Omeg_surf'] # Omega superficial  (s-1)
ccc7 = myfile8['Omeg_cen'] # Omega central  (s-1)
ddd7 = myfile8['Rp/Req'] # Rp/Requiv
eee7 = myfile8['Md/Md(0)'] # Md/Md(0)
fff7 = myfile8['v_crit1'] # Velocidad crítica 1 (km/s)
ggg7 = myfile8['v_crit2'] # Velocidad crítica 2 (km/s)
hhh7 = myfile8['v_equa'] # Velocidad crítica 2 (km/s)
iii7 = myfile8['Om/Om_cr'] # Omega/ Omega crítica
jjj7 = myfile8['Gamma_Ed'] # Gamma de Eddington
kkk7 = myfile8['lg(Mdot_mech)'] #log Msun (Msun/yr)
lll7 = myfile8['L_tot'] #Luminosidad total

####################################################
#Asignación de las variables a la estrella de 15.0Msun:
####################################################

xx8 = myfile9['time'] #Tiempo en (yr)
yy8 = myfile9['mass'] #Masa en (Msun)
zz8 = myfile9['lg(L)'] #Log de la luminosidad (en Lsun)
aa8 = myfile9['1H_surf'] # 1H superficial (Fracc. en masa)
bb8 = myfile9['4He_surf'] # 4He superficial (Fracc. en masa)
cc8 = myfile9['12C_surf'] # 12C superficial (Fracc. en masa)
dd8 = myfile9['13C_surf'] # 13C superficial (Fracc. en masa)
ee8 = myfile9['14N_surf'] # 14N superficial (Fracc. en masa)
ff8 = myfile9['16O_surf'] # 16_O superficial (Fracc. en masa)
gg8 = myfile9['17O_surf'] # 17_O superficial (Fracc. en masa)
hh8 = myfile9['18O_surf'] # 18_O superficial (Fracc. en masa)
ii8 = myfile9['20Ne_surf'] # 20Ne superficial (Fracc. en masa)
jj8 = myfile9['22Ne_surf'] # 22Ne superficial (Fracc. en masa)
kk8 = myfile9['26Al_surf'] # 26_Al superficial (Fracc. en masa)
ll8 = myfile9['Mcc/Mt'] # Ratio Mcc/Mt
mm8 =  myfile9['lg(Teff)'] # Log Temperatura (K)
nn8 = myfile9['lg(Md)'] # Log Ms/yr
oo8 = myfile9['lg(rhoc)'] # Log rho crítica (g/cm3)
pp8 = myfile9['lg(Tc)'] # Log T crítica (K)
qq8 = myfile9['1H_cen'] # 1H central (Fracc. en masa)
rr8 = myfile9['4He_cen'] # 4He central (Fracc. en masa)
ss8 = myfile9['12C_cen'] # 12C central (Fracc. en masa)
tt8 = myfile9['13C_cen'] # 13C central (Fracc. en masa)
uu8 = myfile9['14N_cen'] # 14N central (Fracc. en masa)
vv8 = myfile9['16O_cen'] # 16_O central (Fracc. en masa)
ww8 = myfile9['17O_cen'] # 17_O central (Fracc. en masa)
xxx8 = myfile9['18O_cen'] # 18_O central (Fracc. en masa)
yyy8 = myfile9['20Ne_cen'] # 20Ne central (Fracc. en masa)
zzz8 = myfile9['22Ne_cen'] # 22Ne central (Fracc. en masa)
aaa8 = myfile9['26Al_cen'] # 26_Al central (Fracc. en masa)
bbb8 = myfile9['Omeg_surf'] # Omega superficial  (s-1)
ccc8 = myfile9['Omeg_cen'] # Omega central  (s-1)
ddd8 = myfile9['Rp/Req'] # Rp/Requiv
eee8 = myfile9['Md/Md(0)'] # Md/Md(0)
fff8 = myfile9['v_crit1'] # Velocidad crítica 1 (km/s)
ggg8 = myfile9['v_crit2'] # Velocidad crítica 2 (km/s)
hhh8 = myfile9['v_equa'] # Velocidad crítica 2 (km/s)
iii8 = myfile9['Om/Om_cr'] # Omega/ Omega crítica
jjj8 = myfile9['Gamma_Ed'] # Gamma de Eddington
kkk8 = myfile9['lg(Mdot_mech)'] #log Msun (Msun/yr)
lll8 = myfile9['L_tot'] #Luminosidad total

####################################################
#Asignación de las variables a la estrella de 25.0Msun:
####################################################

xx9 = myfile10['time'] #Tiempo en (yr)
yy9 = myfile10['mass'] #Masa en (Msun)
zz9 = myfile10['lg(L)'] #Log de la luminosidad (en Lsun)
aa9 = myfile10['1H_surf'] # 1H superficial (Fracc. en masa)
bb9 = myfile10['4He_surf'] # 4He superficial (Fracc. en masa)
cc9 = myfile10['12C_surf'] # 12C superficial (Fracc. en masa)
dd9 = myfile10['13C_surf'] # 13C superficial (Fracc. en masa)
ee9 = myfile10['14N_surf'] # 14N superficial (Fracc. en masa)
ff9 = myfile10['16O_surf'] # 16_O superficial (Fracc. en masa)
gg9 = myfile10['17O_surf'] # 17_O superficial (Fracc. en masa)
hh9 = myfile10['18O_surf'] # 18_O superficial (Fracc. en masa)
ii9 = myfile10['20Ne_surf'] # 20Ne superficial (Fracc. en masa)
jj9 = myfile10['22Ne_surf'] # 22Ne superficial (Fracc. en masa)
kk9 = myfile10['26Al_surf'] # 26_Al superficial (Fracc. en masa)
ll9 = myfile10['Mcc/Mt'] # Ratio Mcc/Mt
mm9 =  myfile10['lg(Teff)'] # Log Temperatura (K)
nn9 = myfile10['lg(Md)'] # Log Ms/yr
oo9 = myfile10['lg(rhoc)'] # Log rho crítica (g/cm3)
pp9 = myfile10['lg(Tc)'] # Log T crítica (K)
qq9 = myfile10['1H_cen'] # 1H central (Fracc. en masa)
rr9 = myfile10['4He_cen'] # 4He central (Fracc. en masa)
ss9 = myfile10['12C_cen'] # 12C central (Fracc. en masa)
tt9 = myfile10['13C_cen'] # 13C central (Fracc. en masa)
uu9 = myfile10['14N_cen'] # 14N central (Fracc. en masa)
vv9 = myfile10['16O_cen'] # 16_O central (Fracc. en masa)
ww9 = myfile10['17O_cen'] # 17_O central (Fracc. en masa)
xxx9 = myfile10['18O_cen'] # 18_O central (Fracc. en masa)
yyy9 = myfile10['20Ne_cen'] # 20Ne central (Fracc. en masa)
zzz9 = myfile10['22Ne_cen'] # 22Ne central (Fracc. en masa)
aaa9 = myfile10['26Al_cen'] # 26_Al central (Fracc. en masa)
bbb9 = myfile10['Omeg_surf'] # Omega superficial  (s-1)
ccc9 = myfile10['Omeg_cen'] # Omega central  (s-1)
ddd9 = myfile10['Rp/Req'] # Rp/Requiv
eee9 = myfile10['Md/Md(0)'] # Md/Md(0)
fff9 = myfile10['v_crit1'] # Velocidad crítica 1 (km/s)
ggg9 = myfile10['v_crit2'] # Velocidad crítica 2 (km/s)
hhh9 = myfile10['v_equa'] # Velocidad crítica 2 (km/s)
iii9 = myfile10['Om/Om_cr'] # Omega/ Omega crítica
jjj9 = myfile10['Gamma_Ed'] # Gamma de Eddington
kkk9 = myfile10['lg(Mdot_mech)'] #log Msun (Msun/yr)
lll9 = myfile10['L_tot'] #Luminosidad total


####################################################
#Asignación de las variables a la estrella de 40.0Msun:
####################################################

xx10 = myfile11['time'] #Tiempo en (yr)
yy10 = myfile11['mass'] #Masa en (Msun)
zz10 = myfile11['lg(L)'] #Log de la luminosidad (en Lsun)
aa10 = myfile11['1H_surf'] # 1H superficial (Fracc. en masa)
bb10 = myfile11['4He_surf'] # 4He superficial (Fracc. en masa)
cc10 = myfile11['12C_surf'] # 12C superficial (Fracc. en masa)
dd10 = myfile11['13C_surf'] # 13C superficial (Fracc. en masa)
ee10 = myfile11['14N_surf'] # 14N superficial (Fracc. en masa)
ff10 = myfile11['16O_surf'] # 16_O superficial (Fracc. en masa)
gg10 = myfile11['17O_surf'] # 17_O superficial (Fracc. en masa)
hh10 = myfile11['18O_surf'] # 18_O superficial (Fracc. en masa)
ii10 = myfile11['20Ne_surf'] # 20Ne superficial (Fracc. en masa)
jj10 = myfile11['22Ne_surf'] # 22Ne superficial (Fracc. en masa)
kk10 = myfile11['26Al_surf'] # 26_Al superficial (Fracc. en masa)
ll10 = myfile11['Mcc/Mt'] # Ratio Mcc/Mt
mm10 = myfile11['lg(Teff)'] # Log Temperatura (K)
nn10 = myfile11['lg(Md)'] # Log Ms/yr
oo10 = myfile11['lg(rhoc)'] # Log rho crítica (g/cm3)
pp10 = myfile11['lg(Tc)'] # Log T crítica (K)
qq10 = myfile11['1H_cen'] # 1H central (Fracc. en masa)
rr10 = myfile11['4He_cen'] # 4He central (Fracc. en masa)
ss10 = myfile11['12C_cen'] # 12C central (Fracc. en masa)
tt10 = myfile11['13C_cen'] # 13C central (Fracc. en masa)
uu10 = myfile11['14N_cen'] # 14N central (Fracc. en masa)
vv10 = myfile11['16O_cen'] # 16_O central (Fracc. en masa)
ww10 = myfile11['17O_cen'] # 17_O central (Fracc. en masa)
xxx10 = myfile11['18O_cen'] # 18_O central (Fracc. en masa)
yyy10 = myfile11['20Ne_cen'] # 20Ne central (Fracc. en masa)
zzz10 = myfile11['22Ne_cen'] # 22Ne central (Fracc. en masa)
aaa10 = myfile11['26Al_cen'] # 26_Al central (Fracc. en masa)
bbb10 = myfile11['Omeg_surf'] # Omega superficial  (s-1)
ccc10 = myfile11['Omeg_cen'] # Omega central  (s-1)
ddd10 = myfile11['Rp/Req'] # Rp/Requiv
eee10 = myfile11['Md/Md(0)'] # Md/Md(0)
fff10 = myfile11['v_crit1'] # Velocidad crítica 1 (km/s)
ggg10 = myfile11['v_crit2'] # Velocidad crítica 2 (km/s)
hhh10 = myfile11['v_equa'] # Velocidad crítica 2 (km/s)
iii10 = myfile11['Om/Om_cr'] # Omega/ Omega crítica
jjj10 = myfile11['Gamma_Ed'] # Gamma de Eddington
kkk10 = myfile11['lg(Mdot_mech)'] #log Msun (Msun/yr)
lll10 = myfile11['L_tot'] #Luminosidad total

# %% [markdown]
# ## Abundancias Xcen y Hcen para estrellas de M = 5 y 9 Msun

# %%
#Representación de las abundancias de H_cen y He_cen para estrellas:
#5 - 9 Msun
#Eje X = Años (yr)
#Eje Y = Abundancias (fracc. masa)
plt.figure(figsize=(10, 8))
plt.plot(xx6/10**6,qq6, linewidth=1, color ='blue', label = r'$H_{cen}$ para $M=5M_{\odot}$', linestyle = 'solid') # H_central para M= 5Msun
plt.plot(xx6/10**6,rr6, linewidth=1, color ='red', label = r'$He_{cen}$ para $M=5M_{\odot}$',linestyle = 'solid') # He_central para M= 5Msun
plt.plot(xx7/10**6,qq7, linewidth=2, color ='blue', label = r'$H_{cen}$ para $M=9M_{\odot}$',linestyle = 'dashed') # H_central para M= 9Msun
plt.plot(xx7/10**6,rr7, linewidth=2, color ='red', label = r'$He_{cen}$ para $M=9M_{\odot}$',linestyle = 'dashed') # He_central para M= 9Msun
plt.title('Evolución temporal de $H_{cen}$ y $He_{cen}$', size =20)
plt.xlabel('Tiempo en Millones de Años', size = 15)
plt.ylabel('Abundancia central', size = 15)
plt.legend(loc = "upper center")
plt.minorticks_on()
plt.grid(b=True,which='major', color='#666666', linestyle='-')
plt.grid(b=True,which='minor', color='#888888', linestyle='-', alpha=0.5)

#La estrella habrá salido de la secuencia principal cuando H_central sea menor que:
# 10^(-5)

#Para la estrella de M = 5Msun:
for i in range(len(qq6)):
  if qq6[i]<10**(-5):
    timeMS5=xx6[i]-xx6[0]
    break

#Para la estrella de M = 9Msun:
for i in range(len(qq7)):
  if qq7[i]<10**(-5):
    timeMS9=xx7[i]-xx7[0]
    break

print('La estrella de 5Msun ha estado', format(timeMS5,'.2E'), 'años en la MS y la estrella de 9Msun ha estado', format(timeMS9,'.2E'), 'años')
# Out:
# La estrella de 5Msun ha estado 8.82E+07 años en la MS y la estrella de 9Msun ha estado 2.63E+07 años

# %%
M5sun=1/((5*2*10**30))**2
M9sun=1/((9*2*10**30))**2
ratioM5M9=M5sun/M9sun
print(str(ratioM5M9))
M5sunp=8.82*10**7
M9sunp=2.63*10**7
ratioM5M9p=M5sunp/M9sunp
print(str(ratioM5M9p))
# Out:
# 3.24
# 3.3536121673003803

# %% [markdown]
# ## Para los modelos con M = 0.8, 1, 1.25, 1.5, 2, 3, 5, 9, 15, 25, 40 Msun.

# %% [markdown]
# ### Trazas Evolutivas. Diagramas HR.

# %%
#Se crea los diagramas HR:
plt.figure(figsize=(9, 9))
plt.plot(mm,zz,linewidth=1, color='r', label='$M=0.8M_{\odot}$ sin rotación') #Traza para 0.8Msun (log(Teff) frente a Log(L))
plt.plot(mm1,zz1,linewidth=1, color='b', label='$M=1.0M_{\odot}$ sin rotación') #Traza para 1.0Msun (log(Teff) frente a Log(L))
plt.plot(mm2,zz2,linewidth=1, color='g', label='$M=1.25M_{\odot}$ sin rotación') #Traza para 1.25Msun (log(Teff) frente a Log(L))
plt.plot(mm3,zz3,linewidth=1, color='k', label='$M=1.5M_{\odot}$ sin rotación') #Traza para 1.5Msun (log(Teff) frente a Log(L))
plt.plot(mm4,zz4,linewidth=1, color='c', label='$M=2.0M_{\odot}$ sin rotación') #Traza para 2.0Msun (log(Teff) frente a Log(L))
plt.plot(mm5,zz5,linewidth=1, color='m', label='$M=3.0M_{\odot}$ sin rotación') #Traza para 3.0Msun (log(Teff) frente a Log(L))
plt.plot(mm6,zz6,linewidth=1, color='r', label='$M=5.0M_{\odot}$ sin rotación') #Traza para 5.0Msun (log(Teff) frente a Log(L))
plt.plot(mm7,zz7,linewidth=1, color='skyblue', label='$M=9.0M_{\odot}$ sin rotación') #Traza para 9.0Msun (log(Teff) frente a Log(L))
plt.plot(mm8,zz8,linewidth=1, color='gold', label='$M=15.0M_{\odot}$ sin rotación') #Traza para 15.0Msun (log(Teff) frente a Log(L))
plt.plot(mm9,zz9,linewidth=1, color='brown', label='$M=25.0M_{\odot}$ sin rotación') #Traza para 25.0Msun (log(Teff) frente a Log(L))
plt.plot(mm10,zz10,linewidth=1, color='grey', label='$M=40.0M_{\odot}$ sin rotación') #Traza para 40.0Msun (log(Teff) frente a Log(L))


plt.gca().invert_xaxis()
plt.title('Trazas evolutivas para estrellas con distinta masa M', size =18)
plt.xlabel('$Log(T_{eff} \;[K])$', size =15)
plt.ylabel('$Log(L/L_{\odot})$', size =15)
plt.legend(loc='lower center', bbox_to_anchor=(0.35, 0), ncol =2, fancybox =True, shadow =True, fontsize=9)

# %% [markdown]
# ### ZAMS y TAMS. Estrellas que dejan la MS.

# %%
# Visualización de la ZAMS para el mismo rango. El primer dato, se corresponde al de la ZAMS.(cuando las estrellas entran en la MS)
plt.figure(figsize=(6, 7))
plt.scatter(mm[0],zz[0],linewidth=1, color='r') #ZAMS[0]: Traza para 0.8Msun (log(Teff) frente a Log(L))
plt.scatter(mm1[0],zz1[0],linewidth=1, color='b') #ZAMS[0]: Traza para 1.0Msun (log(Teff) frente a Log(L))
plt.scatter(mm2[0],zz2[0],linewidth=1, color='g') #ZAMS[0]: Traza para 1.25Msun (log(Teff) frente a Log(L))
plt.scatter(mm3[0],zz3[0],linewidth=1, color='k') #ZAMS[0]: Traza para 1.5Msun (log(Teff) frente a Log(L))
plt.scatter(mm4[0],zz4[0],linewidth=1, color='c') #ZAMS[0]: Traza para 2.0Msun (log(Teff) frente a Log(L))
plt.scatter(mm5[0],zz5[0],linewidth=1, color='m') #ZAMS[0]: Traza para 3.0Msun (log(Teff) frente a Log(L))
plt.scatter(mm6[0],zz6[0],linewidth=1, color='r') #ZAMS[0]: Traza para 5.0Msun (log(Teff) frente a Log(L))
plt.scatter(mm7[0],zz7[0],linewidth=1, color='skyblue') #ZAMS[0]: Traza para 9.0Msun (log(Teff) frente a Log(L))
plt.scatter(mm8[0],zz8[0],linewidth=1, color='gold') #ZAMS[0]: Traza para 15.0Msun (log(Teff) frente a Log(L))
plt.scatter(mm9[0],zz9[0],linewidth=1, color='brown') #ZAMS[0]: Traza para 25.0Msun (log(Teff) frente a Log(L))
plt.scatter(mm10[0],zz10[0],linewidth=1, color='grey') #ZAMS[0]: Traza para 40.0Msun (log(Teff) frente a Log(L))

#Cálculo del momento en que cada estrella sale de la MS. Se grafica su evolución, hasta ese momento:
FLimit=10**(-4) #Fracción en masa muy pequeña. Valor estimado cercano a cero.
#M = 0.8 Msun:
for N in range(len(qq)):  #Range(H1_central)
  if qq[N]<FLimit: #Cuando se llega a la fracción límite
    N0p8=N #Se iguala el contador a otra nueva variable
    T0p8=xx[N0p8]-xx[0] #Se calcula la diferencia de tiempos
    break
#M = 1.0 Msun:
for N in range(len(qq1)):  #Range(H1_central)
  if qq1[N]<FLimit: #Cuando se llega a la fracción límite
    N1=N #Se iguala el contador a otra nueva variable
    T1=xx1[N1]-xx1[0] #Se calcula la diferencia de tiempos
    break
#M = 1.25 Msun:
for N in range(len(qq2)):  #Range(H1_central)
  if qq2[N]<FLimit: #Cuando se llega a la fracción límite
    N1p25=N #Se iguala el contador a otra nueva variable
    T1p25=xx2[N1p25]-xx2[0] #Se calcula la diferencia de tiempos
    break
#M = 1.5 Msun:
for N in range(len(qq3)):  #Range(H1_central)
  if qq3[N]<FLimit: #Cuando se llega a la fracción límite
    N1p5=N #Se iguala el contador a otra nueva variable
    T1p5=xx3[N1p5]-xx3[0] #Se calcula la diferencia de tiempos
    break
#M = 2.0 Msun:
for N in range(len(qq4)):  #Range(H1_central)
  if qq4[N]<FLimit: #Cuando se llega a la fracción límite
    N2=N #Se iguala el contador a otra nueva variable
    T2=xx4[N2]-xx4[0] #Se calcula la diferencia de tiempos
    break
#M = 3.0 Msun:
for N in range(len(qq5)):  #Range(H1_central)
  if qq5[N]<FLimit: #Cuando se llega a la fracción límite
    N3=N #Se iguala el contador a otra nueva variable
    T3=xx5[N3]-xx5[0] #Se calcula la diferencia de tiempos
    break
#M = 5.0 Msun:
for N in range(len(qq6)):  #Range(H1_central)
  if qq6[N]<FLimit: #Cuando se llega a la fracción límite
    N5=N #Se iguala el contador a otra nueva variable
    T5=xx6[N5]-xx6[0] #Se calcula la diferencia de tiempos
    break
#M = 9.0 Msun:
for N in range(len(qq7)):  #Range(H1_central)
  if qq7[N]<FLimit: #Cuando se llega a la fracción límite
    N9=N #Se iguala el contador a otra nueva variable
    T9=xx7[N9]-xx7[0] #Se calcula la diferencia de tiempos
    break
#M = 15.0 Msun:
for N in range(len(qq8)):  #Range(H1_central)
  if qq8[N]<FLimit: #Cuando se llega a la fracción límite
    N15=N #Se iguala el contador a otra nueva variable
    T15=xx8[N15]-xx8[0] #Se calcula la diferencia de tiempos
    break
#M = 25.0 Msun:
for N in range(len(qq9)):  #Range(H1_central)
  if qq9[N]<FLimit: #Cuando se llega a la fracción límite
    N25=N #Se iguala el contador a otra nueva variable
    T25=xx9[N25]-xx9[0] #Se calcula la diferencia de tiempos
    break
#M = 40.0 Msun:
for N in range(len(qq10)):  #Range(H1_central)
  if qq10[N]<FLimit: #Cuando se llega a la fracción límite
    N40=N #Se iguala el contador a otra nueva variable
    T40=xx10[N40]-xx10[0] #Se calcula la diferencia de tiempos
    break

# Visualización de la TAMS para el mismo rango. El primer dato, se corresponde al de la ZAMS.(cuando las estrellas entran en la MS)
plt.scatter(mm[N0p8],zz[N0p8],linewidth=1, color='r') #ZAMS[0]: Traza para 0.8Msun (log(Teff) frente a Log(L))
plt.scatter(mm1[N1],zz1[N1],linewidth=1, color='b') #ZAMS[0]: Traza para 1.0Msun (log(Teff) frente a Log(L))
plt.scatter(mm2[N1p25],zz2[N1p25],linewidth=1, color='g') #ZAMS[0]: Traza para 1.25Msun (log(Teff) frente a Log(L))
plt.scatter(mm3[N1p5],zz3[N1p5],linewidth=1, color='k') #ZAMS[0]: Traza para 1.5Msun (log(Teff) frente a Log(L))
plt.scatter(mm4[N2],zz4[N2],linewidth=1, color='c') #ZAMS[0]: Traza para 2.0Msun (log(Teff) frente a Log(L))
plt.scatter(mm5[N3],zz5[N3],linewidth=1, color='m') #ZAMS[0]: Traza para 3.0Msun (log(Teff) frente a Log(L))
plt.scatter(mm6[N5],zz6[N5],linewidth=1, color='r') #ZAMS[0]: Traza para 5.0Msun (log(Teff) frente a Log(L))
plt.scatter(mm7[N9],zz7[N9],linewidth=1, color='skyblue') #ZAMS[0]: Traza para 9.0Msun (log(Teff) frente a Log(L))
plt.scatter(mm8[N15],zz8[N15],linewidth=1, color='gold') #ZAMS[0]: Traza para 15.0Msun (log(Teff) frente a Log(L))
plt.scatter(mm9[N25],zz9[N25],linewidth=1, color='brown') #ZAMS[0]: Traza para 25.0Msun (log(Teff) frente a Log(L))
plt.scatter(mm10[N40],zz10[N40],linewidth=1, color='grey') #ZAMS[0]: Traza para 40.0Msun (log(Teff) frente a Log(L))

#Se dibujan estas trazas evolutivas sobre los plots previos:
plt.plot(mm[0:N0p8],zz[0:N0p8],linewidth=1, color='r', label='$M=0.8M_{\odot}$ sin rotación') #ZAMS: Traza para 0.8Msun (log(Teff) frente a Log(L))
plt.plot(mm1[0:N1],zz1[0:N1],linewidth=1, color='b', label='$M=1.0M_{\odot}$ sin rotación') #ZAMS: Traza para 1.0Msun (log(Teff) frente a Log(L))
plt.plot(mm2[0:N1p25],zz2[0:N1p25],linewidth=1, color='g', label='$M=1.25M_{\odot}$ sin rotación') #ZAMS: Traza para 1.25Msun (log(Teff) frente a Log(L))
plt.plot(mm3[0:N1p5],zz3[0:N1p5],linewidth=1, color='k', label='$M=1.5M_{\odot}$ sin rotación') #ZAMS: Traza para 1.5Msun (log(Teff) frente a Log(L))
plt.plot(mm4[0:N2],zz4[0:N2],linewidth=1, color='c', label='$M=2.0M_{\odot}$ sin rotación') #ZAMS: Traza para 2.0Msun (log(Teff) frente a Log(L))
plt.plot(mm5[0:N3],zz5[0:N3],linewidth=1, color='m', label='$M=3.0M_{\odot}$ sin rotación') #ZAMS: Traza para 3.0Msun (log(Teff) frente a Log(L))
plt.plot(mm6[0:N5],zz6[0:N5],linewidth=1, color='r', label='$M=5.0M_{\odot}$ sin rotación') #ZAMS: Traza para 5.0Msun (log(Teff) frente a Log(L))
plt.plot(mm7[0:N9],zz7[0:N9],linewidth=1, color='skyblue', label='$M=9.0M_{\odot}$ sin rotación') #ZAMS: Traza para 9.0Msun (log(Teff) frente a Log(L))
plt.plot(mm8[0:N15],zz8[0:N15],linewidth=1, color='gold', label='$M=15.0M_{\odot}$ sin rotación') #ZAMS: Traza para 15.0Msun (log(Teff) frente a Log(L))
plt.plot(mm9[0:N25],zz9[0:N25],linewidth=1, color='brown', label='$M=25.0M_{\odot}$ sin rotación') #ZAMS: Traza para 25.0Msun (log(Teff) frente a Log(L))
plt.plot(mm10[0:N40],zz10[0:N40],linewidth=1, color='grey', label='$M=40.0M_{\odot}$ sin rotación') #ZAMS: Traza para 40.0Msun (log(Teff) frente a Log(L))
#Línea ZAMS (EJE X):
arrayXZAMS= [mm[0], mm1[0], mm2[0], mm3[0], mm4[0], mm5[0], mm6[0], mm7[0], mm8[0], mm9[0], mm10[0]]
#Línea TAMS(EJE X):
arrayXTAMS = [mm[N0p8], mm1[N1], mm2[N1p25], mm3[N1p5], mm4[N2], mm5[N3], mm6[N5], mm7[N9], mm8[N15], mm9[N25], mm10[N40]]
#Línea ZAMS (EJE Y):
arrayYZAMS= [zz[0], zz1[0], zz2[0], zz3[0], zz4[0], zz5[0], zz6[0], zz7[0], zz8[0], zz9[0], zz10[0]]
#Línea TAMS(EJE Y):
arrayYTAMS = [zz[N0p8], zz1[N1], zz2[N1p25], zz3[N1p5], zz4[N2], zz5[N3], zz6[N5], zz7[N9], zz8[N15], zz9[N25], zz10[N40]]
#Representación ZAMS y TAMS:
#plt.plot(arrayXZAMS, arrayYZAMS, color= 'red', label = 'ZAMS', linestyle ='dashed')
#plt.plot(arrayXTAMS, arrayYTAMS, color= 'dimgray', label = 'TAMS', linestyle ='dashed')
#Representación conjunta:
plt.gca().invert_xaxis()
plt.title('ZAMS, TAMS y evolución en la secuencia principal (MS)', size =18)
plt.xlabel('$Log(T_{eff} \;[K])$', size =15)
plt.ylabel('$Log(L/L_{\odot})$', size =15)
plt.legend(loc='lower right', bbox_to_anchor=(2.0, 0.2), ncol =2, fancybox =True, shadow =True)

# %%
#Representación de la ZAMS y la TAMS:
plt.figure(figsize=(6, 7))
plt.plot(arrayXZAMS, arrayYZAMS, color= 'red', label = 'ZAMS', linestyle ='dashed')
plt.plot(arrayXTAMS, arrayYTAMS, color= 'blue', label = 'TAMS', linestyle ='dashed')
plt.gca().invert_xaxis()
plt.title('ZAMS y TAMS', size =18)
plt.xlabel('$Log(T_{eff} \;[K])$', size =15)
plt.ylabel('$Log(L/L_{\odot})$', size =15)
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ### Edad de las estrellas cuando llegan al MS (ZAMS) y al salir de la ZAMS

# %%
T40/10**9
# Out:
# 0.00444062949584532

# %% [markdown]
# ### Relación L - M para las estrellas de la ZAMS

# %%
# Se busca graficar la relación entre la masa y la luminosidad de las estrellas de la ZAMS al entrar en la MS.
plt.figure(figsize=(8, 9))
plt.scatter(10**zz[0],yy[0], marker='^', color='r', label='$M=0.8M_{\odot}$ sin rotación') #Relación L-M: 0.8Msun (log(Teff) frente a Log(L))
plt.scatter(10**zz1[0],yy1[0], marker='^', color='b', label='$M=1.0M_{\odot}$ sin rotación') #Relación L-M: Traza para 1.0Msun (log(Teff) frente a Log(L))
plt.scatter(10**zz2[0],yy2[0], marker='^', color='g', label='$M=1.25M_{\odot}$ sin rotación') #Relación L-M: Traza para 1.25Msun (log(Teff) frente a Log(L))
plt.scatter(10**zz3[0],yy3[0], marker='^', color='k', label='$M=1.5M_{\odot}$ sin rotación') #Relación L-M: Traza para 1.5Msun (log(Teff) frente a Log(L))
plt.scatter(10**zz4[0],yy4[0], marker='^', color='c', label='$M=2.0M_{\odot}$ sin rotación') #Relación L-M: Traza para 2.0Msun (log(Teff) frente a Log(L))
plt.scatter(10**zz5[0],yy5[0], marker='^', color='m', label='$M=3.0M_{\odot}$ sin rotación') #Relación L-M: Traza para 3.0Msun (log(Teff) frente a Log(L))
plt.scatter(10**zz6[0],yy6[0], marker='^', color='r', label='$M=5.0M_{\odot}$ sin rotación') #Relación L-M: Traza para 5.0Msun (log(Teff) frente a Log(L))
plt.scatter(10**zz7[0],yy7[0], marker='^', color='skyblue', label='$M=9.0M_{\odot}$ sin rotación') #Relación L-M: Traza para 9.0Msun (log(Teff) frente a Log(L))
plt.scatter(10**zz8[0],yy8[0], marker='^', color='gold', label='$M=15.0M_{\odot}$ sin rotación') #Relación L-M: Traza para 15.0Msun (log(Teff) frente a Log(L))
plt.scatter(10**zz9[0],yy9[0], marker='^', color='brown', label='$M=25.0M_{\odot}$ sin rotación') #Relación L-M: Traza para 25.0Msun (log(Teff) frente a Log(L))
plt.scatter(10**zz10[0],yy10[0], marker='^', color='grey', label='$M=40.0M_{\odot}$ sin rotación') #Relación L-M: Traza para 40.0Msun (log(Teff) frente a Log(L))

# Se calcula el valor para el coeficiente beta al hacer un ajuste para la función M = cte*L**Beta
Msol = 1.988*10**30 #Masa del sol (kg)
Lsol = 3.828*10**26 #Luminosidad solar (W)
# Se almacena en un array:
Lnum =[10**zz[0], 10**zz1[0], 10**zz2[0], 10**zz3[0], 10**zz4[0], 10**zz5[0], 10**zz6[0], 10**zz7[0], 10**zz8[0], 10**zz9[0], 10**zz10[0]] #Luminosidad total
Mnum = [yy[0], yy1[0], yy2[0], yy3[0], yy4[0], yy5[0], yy6[0], yy7[0], yy8[0], yy9[0], yy10[0]] # Masa total

#Se define la función:
def Mtfunction(Lteo,A, beta):
  return A*Lteo**(beta)

#Se ajusta la función; se imprime el valor de alpha:
beta, covar =curve_fit(Mtfunction,Lnum,Mnum)
alpha=1/beta[1]
print('El exponente de L, es:', beta[1])
print('A es la relación L$\prop$ $M^{\alpha}$, $\alpha$=', alpha)
#Se dibuja la función resultante sobre nuestros datos:
Lteor =np.linspace(10**zz[0], 10**zz10[0],1000)
plt.plot(Lteor, Mtfunction(Lteor, beta[0], beta[1]), label ='Ajuste')
plt.title ('Luminosidad vs Masa',size =18)
plt.xlabel ('$L/L_{\odot}$',size =15)
plt.ylabel ('$M/M_{\odot}$',size =15)
plt.legend (loc='lower right', bbox_to_anchor =(1.0 , 0.0) , ncol =2, fancybox =True , shadow = True )
# Out:
# El exponente de L, es: 0.366454889349186
# A es la relación L$\prop$ $M^{lpha}$, $lpha$= 2.7288488407835763

# %% [markdown]
# ### Relación $ρ_{c}$ - M para estrellas de la ZAMS.

# %%
# Se busca graficar la relación entre la densidad central y la masa de las estrellas de la ZAMS al entrar en la MS.
plt.figure(figsize=(8, 9))
plt.scatter(10**oo[0],yy[0], marker='^', color='r', label='$M=0.8M_{\odot}$ sin rotación') #Relación Rhoc-M: 0.8Msun
plt.scatter(10**oo1[0],yy1[0], marker='^', color='b', label='$M=1.0M_{\odot}$ sin rotación') #Relación Rhoc-M: Traza para 1.0Msun
plt.scatter(10**oo2[0],yy2[0], marker='^', color='g', label='$M=1.25M_{\odot}$ sin rotación') #Relación Rhoc-M: Traza para 1.25Msun
plt.scatter(10**oo3[0],yy3[0], marker='^', color='k', label='$M=1.5M_{\odot}$ sin rotación') #Relación Rhoc-M: Traza para 1.5Msun
plt.scatter(10**oo4[0],yy4[0], marker='^', color='c', label='$M=2.0M_{\odot}$ sin rotación') #Relación Rhoc-M: Traza para 2.0Msun
plt.scatter(10**oo5[0],yy5[0], marker='^', color='m', label='$M=3.0M_{\odot}$ sin rotación') #Relación Rhoc-M: Traza para 3.0Msun
plt.scatter(10**oo6[0],yy6[0], marker='^', color='r', label='$M=5.0M_{\odot}$ sin rotación') #Relación Rhoc-M: Traza para 5.0Msun
plt.scatter(10**oo7[0],yy7[0], marker='^', color='skyblue', label='$M=9.0M_{\odot}$ sin rotación') #Relación Rhoc-M: Traza para 9.0Msun
plt.scatter(10**oo8[0],yy8[0], marker='^', color='gold', label='$M=15.0M_{\odot}$ sin rotación') #Relación Rhoc-M: Traza para 15.0Msun
plt.scatter(10**oo9[0],yy9[0], marker='^', color='brown', label='$M=25.0M_{\odot}$ sin rotación') #Relación Rhoc-M: Traza para 25.0Msun
plt.scatter(10**oo10[0],yy10[0], marker='^', color='grey', label='$M=40.0M_{\odot}$ sin rotación') #Relación Rhoc-M: Traza para 40.0Msun

# Definimos los array:
rhocnum =[10**oo[0], 10**oo1[0], 10**oo2[0], 10**oo3[0], 10**oo4[0], 10**oo5[0], 10**oo6[0], 10**oo7[0], 10**oo8[0], 10**oo9[0], 10**oo10[0]] #Densidad central total
Mnum = [yy[0], yy1[0], yy2[0], yy3[0], yy4[0], yy5[0], yy6[0], yy7[0], yy8[0], yy9[0], yy10[0]] # Masa total

#Se define la función:
def Mtfunctrho(rhoc,A, betarho):
  return A*rhoc**(betarho)

#Se ajusta la función; se imprime el valor de alpha:
betarho, covar =curve_fit(Mtfunctrho,rhocnum,Mnum)
alpha=1/betarho[1]
print('El exponente de rhoc, es:', betarho[1])
print('A es la relación $\rhoc \prop$ M^{\alpha}$, $\alpha$=', alpha)
#Se dibuja la función resultante sobre nuestros datos:
rhocteor =np.linspace(10**oo[0], 10**oo10[0],1000)
plt.plot(rhocteor, Mtfunctrho(rhocteor, betarho[0], betarho[1]), label ='Ajuste')
plt.title ('Densidad central vs Masa',size =18)
plt.xlabel ('$ρ_{c}$ (g/cm3)',size =15)
plt.ylabel ('$M/M_{\odot}$',size =15)
plt.legend (loc='lower right', bbox_to_anchor =(1.0 , 0.45) , ncol =2, fancybox =True , shadow = True )
# Out:
# El exponente de rhoc, es: -1.1514716959912021
# hoc \prop$ M^{lpha}$, $lpha$= -0.868453826074454

# %% [markdown]
# ### Relación T - M para estrellas de la ZAMS.

# %%
# Se busca graficar la relación entre la Temperatura y la masa de las estrellas de la ZAMS al entrar en la MS.
plt.figure(figsize=(8, 9))
plt.scatter(10**pp[0],yy[0], marker='^', color='r', label='$M=0.8M_{\odot}$ sin rotación') #Relación T-M: 0.8Msun
plt.scatter(10**pp1[0],yy1[0], marker='^', color='b', label='$M=1.0M_{\odot}$ sin rotación') #Relación T-M: Traza para 1.0Msun
plt.scatter(10**pp2[0],yy2[0], marker='^', color='g', label='$M=1.25M_{\odot}$ sin rotación') #Relación T-M: Traza para 1.25Msun
plt.scatter(10**pp3[0],yy3[0], marker='^', color='k', label='$M=1.5M_{\odot}$ sin rotación') #Relación T-M: Traza para 1.5Msun
plt.scatter(10**pp4[0],yy4[0], marker='^', color='c', label='$M=2.0M_{\odot}$ sin rotación') #Relación T-M: Traza para 2.0Msun
plt.scatter(10**pp5[0],yy5[0], marker='^', color='m', label='$M=3.0M_{\odot}$ sin rotación') #Relación T-M: Traza para 3.0Msun
plt.scatter(10**pp6[0],yy6[0], marker='^', color='r', label='$M=5.0M_{\odot}$ sin rotación') #Relación T-M: Traza para 5.0Msun
plt.scatter(10**pp7[0],yy7[0], marker='^', color='skyblue', label='$M=9.0M_{\odot}$ sin rotación') #Relación T-M: Traza para 9.0Msun
plt.scatter(10**pp8[0],yy8[0], marker='^', color='gold', label='$M=15.0M_{\odot}$ sin rotación') #Relación T-M: Traza para 15.0Msun
plt.scatter(10**pp9[0],yy9[0], marker='^', color='brown', label='$M=25.0M_{\odot}$ sin rotación') #Relación T-M: Traza para 25.0Msun
plt.scatter(10**pp10[0],yy10[0], marker='^', color='grey', label='$M=40.0M_{\odot}$ sin rotación') #Relación T-M: Traza para 40.0Msun

# Definimos los array:
Tcnum =[10**pp[0], 10**pp1[0], 10**pp2[0], 10**pp3[0], 10**pp4[0], 10**pp5[0], 10**pp6[0], 10**pp7[0], 10**pp8[0], 10**pp9[0], 10**pp10[0]] #Tc total
Mnum = [yy[0], yy1[0], yy2[0], yy3[0], yy4[0], yy5[0], yy6[0], yy7[0], yy8[0], yy9[0], yy10[0]] # Masa total

beta0 =4.0
#Se define la función:
def MtfuncT(Tc,betaT):
  return Tc**(betaT)/Msol

#Se ajusta la función; se imprime el valor de alpha:
betaTc, covar =curve_fit(MtfuncT,Tcnum,Mnum,beta0)
alpha=1/betaTc
print('El exponente de Tc, es:', betaTc)
print('La relación $T_¨{c} \prop$ M^{\alpha}$, $\alpha$=', alpha)
#Se dibuja la función resultante sobre nuestros datos:
Tcteor =np.linspace(10**pp[0], 10**pp10[0],1000)
plt.plot(Tcteor, MtfuncT(Tcteor, betaTc), label ='Ajuste')
plt.title ('Temperatura central vs Masa',size =18)
plt.xlabel ('$T_{c}$ (K)',size =15)
plt.ylabel ('$M/M_{\odot}$',size =15)
plt.legend (loc='upper right', bbox_to_anchor =(0.8 , 1.0) , ncol = 2, fancybox =True , shadow = True)
# Out:
# El exponente de Tc, es: [4.17934755]
# La relación $T_¨{c} \prop$ M^{lpha}$, $lpha$= [0.2392718]

# %% [markdown]
# ## Para los modelos estelares: M = 1, 3, 9 y 40$M_{\odot}$, se pide:

# %% [markdown]
# ### Representación de trazas de los centros de las estrellas en el plano log $T$, log $\rho$

# %%
# Visualización de las relaciones Tc -rhoc a lo largo de la evolución para las masas: 1, 3, 9 y 40 Msun:
#ZAMS:
plt.figure(figsize=(10, 11))
plt.scatter(pp1[0],oo1[0],marker='o', color='b') #Traza para 1.0Msun
plt.scatter(pp5[0],oo5[0],marker='o', color='m') # Traza para 3.0Msun
plt.scatter(pp7[0],oo7[0],marker='o', color='r') # Traza para 9.0Msun
plt.scatter(pp10[0],oo10[0],marker='o', color='g') # Traza para 40.0Msun
#TAMS:
plt.scatter(pp1[N1-1],oo1[N1-1],marker='o', color='b') #Traza para 1.0Msun
plt.scatter(pp5[N3-1],oo5[N3-1],marker='o', color='m') # Traza para 3.0Msun
plt.scatter(pp7[N9],oo7[N9],marker='o', color='r') # Traza para 9.0Msun
plt.scatter(pp10[N40-1],oo10[N40-1],marker='o', color='g') # Traza para 40.0Msun
# Se grafica la salida de la MS:
plt.plot(pp1[0:N1],oo1[0:N1],linewidth=3, color='b', label='$M=1.0M_{\odot}$ sr') #Traza para 1.0Msun
plt.plot(pp5[0:N3],oo5[0:N3],linewidth=3, color='m', label='$M=3.0M_{\odot}$ sr') # Traza para 3.0Msun
plt.plot(pp7[0:N9+1],oo7[0:N9+1],linewidth=3, color='r', label='$M=9.0M_{\odot}$ sr') # Traza para 9.0Msun
plt.plot(pp10[0:N40],oo10[0:N40],linewidth=3, color='g', label='$M=40.0M_{\odot}$ sr') # Traza para 40.0Msun
# Se grafica toda la traza:
plt.plot(pp1,oo1,linewidth=1, color='b', label='$M=1.0M_{\odot}$ sr') #Traza para 1.0Msun
plt.plot(pp5,oo5,linewidth=1, color='m', label='$M=3.0M_{\odot}$ sr') # Traza para 3.0Msun
plt.plot(pp7,oo7,linewidth=1, color='r', label='$M=9.0M_{\odot}$ sr') # Traza para 9.0Msun
plt.plot(pp10,oo10,linewidth=1, color='g', label='$M=40.0M_{\odot}$ sr') # Traza para 40.0Msun
#Regiones dominadas por la radiación, gas ideal, degenerado y degenerado - relativista:
# Definición de constantes:
sigmab = 5.67**-8 #J/s m^2 K^4
c= 3*10**8 #m/s
a=4*sigmab/c # J/m^3 K^4
K0 = 1.38*10**-23/(1.29*1.66*10**-27) #J / kg k
K1 = 10**7/ 2**(5/3) #m ^4 kg^(-2/3) s^(-2)
K2 = 1.24*10**10/ 2**(4/3) # m^3 kg^(-1/3) s^(-2)
#Se grafican las relaciones:
logTc =np.linspace(0.0, 9.25, len(pp1))
RadIdeal=3*logTc -22.74
DegIdeal =3/2*logTc -6.55
DegDegrel =np.full(len(logTc), 6.3)
DegrelIdeal =3*logTc -19.4

for i in range(len(logTc)):
  if logTc[i]<8.56:
    ia=i
  else:
    break
#Visualización de los gráficos.
plt.plot(logTc[0:ia], DegIdeal[0:ia], color='grey',linestyle='dashed')
plt.plot(logTc[0:ia], DegDegrel[0:ia], color='grey',linestyle='dashed')
plt.plot(logTc[ia:len(logTc)-1], DegrelIdeal[ia:len(logTc)-1], color='grey',linestyle='dashed')
plt.plot(logTc,RadIdeal, color ='grey', linestyle='dashed')
plt.title('Temperatura central Vs. Densidad central')
plt.xlabel('log$T_{c}$ (K)', size=15)
plt.ylabel('log $ρ_{c}$ (g/cm3)', size=15)
plt.legend (loc='upper left', bbox_to_anchor =(0.6 ,0.15) ,ncol =2, fancybox =True , shadow =True , fontsize =8)
plt.text (7.25, 7.2, 'Degenerado relativista')
plt.text (7.1, 5.95, 'Degenerado no-relativista')
plt.text (7.1, 0.4, 'Gas Ideal')
plt.text (8.85, 2.5, 'Radiación')
plt.xlim (7.0 ,9.25)
plt.ylim (0.0 ,8.0)
# Out:
# (0.0, 8.0)

# %% [markdown]
# ## Características del modelo: M = 5$M_{\odot}$, se pide:

# %%
#Resultados para M=5Msun

#Se calculará cuando acaba la MS, esto es, cuando deja de haber una cantidad no despreciable de H en el núcleo:
for i in range(len(qq6)):
  if qq6[i]<10**(-5): #qq  = H1_Central
    NH5=i #Se asigna esa posición del array cuando se cumple esa premisa, a una variable. NH1
    break

#Suposición de que se empieza a fusionar He en el núcleo cuando la fracción del mismno baja a 0.01:
fraccionHe=0.0 #Variable para asignar la fracción de He inicial.
for i in range(len(rr6)): #rr = He4_Central
  if fraccionHe-rr6[i]>0.01:
    NHE5=i #Asignación de la posición del array donde se hace la fracción de He menor que 0.01
    break
  fraccionHe=rr6[i]
#Para conocer cuando se está quemando He en el núcleo, se hace lo mismo que con el H:
for i in range(len(rr6)):
  if rr6[i]<10**(-5): #rr  = He4_Central
    NendHe4=i #Se asigna esa posición del array cuando se cumple esa premisa, a una variable. NendHe4
    break

#Cálculo del radio de la estrella teniendo en cuenta su luminosidad y temperatura efectiva.
Lsol = 3.828*10**26 #W (Vatios)
Rsol = 6.96*10**8 #m (metros)
#Cálculo del radio de la estrella:
num = Lsol*(10**zz6)
den = (4*np.pi*sigmab*(10**mm6)**4)
R5M = np.sqrt(num/den)/Rsol

# %%
plt.figure(figsize=(6, 6))
#PRIMER GRÁFICO: Teff vs L:
plt.plot(mm6[0:NH5+1],zz6[0:NH5+1], linewidth=2, color='black', label='MS')
plt.plot(mm6[NH5:NHE5+1],zz6[NH5:NHE5+1], linewidth=2, color='r', label='RGB')
plt.plot(mm6[NHE5:NendHe4+1],zz6[NHE5:NendHe4+1], linewidth=2, color='b', label='BlueLoop')
plt.plot(mm6[NendHe4:],zz6[NendHe4:], linewidth=2, color='green', label='AGB')
#plt.scatter:puntos para cada región:
plt.plot(mm6[NH5],zz6[NH5], marker='o', markersize=10, color='r')
plt.plot(mm6[NHE5],zz6[NHE5], marker='o', markersize=10, color='b')
plt.plot(mm6[NendHe4],zz6[NendHe4], marker='o', markersize=10, color='g')
#Textos:
plt.text (4.20, 2.8, 'MS', color='black', fontsize=14)
plt.text (4.10, 3.1, 'RGB', color='r', fontsize=14)
plt.text (3.9, 3.2, 'Blueloop', color='b', fontsize=14)
plt.text (3.7, 3.3, 'AGB', color='g', fontsize=14)
#Etiquetas de los ejes:
plt.xlabel('$log(T_{eff}$) (K)', fontsize=14)
plt.ylabel('$log(L/L_{\odot})$', fontsize=14)
plt.gca().invert_xaxis()
# Out:
# 6.522479e-06

# %%
#SEGUNDO GRÁFICO: Tiempo vs Abundancias:
plt.figure(figsize=(6, 6))
plt.plot(xx6/10**6, qq6, linewidth=2, color='b', label='H')
plt.plot(xx6/10**6, rr6, linewidth=2, color='r', label='He')
plt.plot(xx6/10**6, ss6, linewidth=2, color='g', label='C')
plt.plot(xx6/10**6, vv6+ww6+xxx6, linewidth=2, color='black', label='O')
#Etiquetas de los ejes:
plt.xlabel('Tiempo (Millones Años)', fontsize=15)
plt.ylabel('Abundancias (fracc. masa)', fontsize=15)
#Lineas verticales:
plt.vlines(xx6[NH5]/10**6, 0, 1, colors = 'grey', linestyle = 'dashed', label='End MS. Start RGB')
plt.vlines(xx6[NHE5]/10**6, 0, 1, colors = 'black', linestyle = 'dotted', label='Start Blue loop')
plt.vlines(xx6[NendHe4]/10**6, 0, 1, colors = 'darkgreen', linestyle = 'dashdot', label='Start AGB')
plt.xlim(75,113)
plt.legend(loc='upper right',ncol=2)
plt.minorticks_on()
plt.grid(b=True, which='major', color='#666666', linestyle='-')

# %%
#TERCER GRÁFICO: RhoC vs. Tc:
plt.figure(figsize=(6, 6))
plt.plot(oo6[0:NH5+1], pp6[0:NH5+1], linewidth=2, color ='black', label='MS')
plt.plot(oo6[NH5:NHE5+1], pp6[NH5:NHE5+1], linewidth=2, color ='r', label='RGB')
plt.plot(oo6[NHE5:NendHe4+1], pp6[NHE5:NendHe4+1], linewidth=2, color ='blue', label='Blueloop')
plt.plot(oo6[NendHe4:], pp6[NendHe4:], linewidth=2, color ='green', label='AGB')
#Scatters:
plt.plot(oo6[NH5], pp6[NH5], marker ='o', markersize = 10, color ='r')
plt.plot(oo6[NHE5], pp6[NHE5], marker ='o', markersize = 10, color ='b')
plt.plot(oo6[NendHe4], pp6[NendHe4], marker ='o', markersize = 10, color ='g')
logrhoc=np.linspace(0,9.25, len(pp6))
plt.plot(DegIdeal, logrhoc, color ='black', linestyle = 'dashed')
plt.plot(RadIdeal, logrhoc, color ='black', linestyle = 'dashed')
#Textos:
plt.text (1, 7.6, 'MS', color='black',  fontsize=14)
plt.text (3.2, 7.6, 'RGB', color='r', fontsize=14)
plt.text (2.7, 8.2, 'Blueloop', color='b', fontsize=14)
plt.text (4.3, 8.4, 'AGB', color='g', fontsize=14)
plt.xlabel('log $ρ_{c}$ (g/cm3)', fontsize=15)
plt.ylabel('$log(T_{c}$) (K)', fontsize=15)
plt.xlim(0.5,6.0)
plt.ylim(7.2,8.7)
# Out:
# (7.2, 8.7)

# %%
#CUARTO GRÁFICO: Tiempo vs R/Rsun:
plt.figure(figsize=(6, 6))
plt.plot(xx6[0:NH5+1]/10**6, R5M[0:NH5+1], linewidth=2, color ='black')
plt.plot(xx6[NH5:NHE5+1]/10**6, R5M[NH5:NHE5+1], linewidth=2, color ='r')
plt.plot(xx6[NHE5:NendHe4+1]/10**6, R5M[NHE5:NendHe4+1], linewidth=2, color ='blue')
plt.plot(xx6[NendHe4:]/10**6, R5M[NendHe4:], linewidth=2, color ='green')
#Scatters:
plt.plot(xx6[NH5]/10**6, R5M[NH5], marker ='o', markersize = 10, color ='r')
plt.plot(xx6[NHE5]/10**6, R5M[NHE5], marker ='o', markersize = 10, color ='b')
plt.plot(xx6[NendHe4]/10**6, R5M[NendHe4], marker ='o', markersize = 10, color ='g')
#Lineas verticales:
plt.vlines(xx6[NH5]/10**6, 0, 40, colors = 'grey', linestyle = 'dashed')
plt.vlines(xx6[NHE5]/10**6, 0, 40, colors = 'grey', linestyle = 'dashed')
plt.vlines(xx6[NendHe4]/10**6, 0, 40, colors = 'grey', linestyle = 'dashed')

#Textos:
plt.text (79, 2, 'MS', color='black',  fontsize=14)
plt.text (85, 10, 'RGB', color='r',  fontsize=14)
plt.text (95, 15, 'Blueloop', color='b',  fontsize=14)
plt.text (105, 20, 'AGB', color='g',  fontsize=14)
plt.xlabel('Tiempo (Millones Años)', fontsize=15)
plt.ylabel('$R/R_{\odot}$', fontsize=15)
plt.xlim(75,113)
plt.ylim(0, 40)
# Out:
# (0.0, 40.0)
